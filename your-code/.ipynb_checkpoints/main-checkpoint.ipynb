# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import pandas as pd
import numpy as np
from scipy.stats import trim_mean, mode, skew, gaussian_kde, pearsonr, spearmanr, beta
from statsmodels.stats.weightstats import ztest as ztest

from scipy.stats import ttest_ind, norm, t
from scipy.stats import f_oneway
from scipy.stats import sem

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents

# %%
# Run this code:
salaries = pd.read_csv('../data/Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
salaries.head()
# Out:
#                   Name                              Job Titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    Annual Salary  Hourly Rate
# 0       101442.0          NaN
# 1        94122.0          NaN
# 2       101592.0          NaN
# 3       110064.0          NaN
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Include only hourly workers
hourly_workers = salaries[salaries['Salary or Hourly'] == 'Hourly']

# Get the "Hourly Rate" columna and check for null values
hourly_rates = hourly_workers['Hourly Rate'].dropna()

# Descriptive Stats
mean_hourly_rate = np.mean(hourly_rates)
median_hourly_rate = np.median(hourly_rates)
std_dev_hourly_rate = np.std(hourly_rates, ddof=1)
sem_hourly_rate = sem(hourly_rates)

# Perform the hypothesis test (one-sample t-test)
# Null hypothesis (H0): The average salary is equal to $30/hr
# Alternative hypothesis (H1): The average salary is different from $30/hr
population_mean = 30
t_stat, p_value = ttest_1samp(hourly_rates, population_mean)

# %%
print("\nDescriptive stats results:")
print(f"  Mean for Hourly Rate: {mean_hourly_rate:.4f}")
print(f"  Median for Hourly Rate: {median_hourly_rate:.4f}")
print(f"  Standard Desviation for Hourly Rate: {std_dev_hourly_rate:.4f}")
print(f"  Standard Error of the Mean (SEM) for Hourly Rate: {sem_hourly_rate:.4f}")

print("\nHypothesis test results:")
print(f"  t-statistic: {t_stat:.2f}")
print(f"  p-value: {p_value:.2e}")
# Out:
# Descriptive stats results:
#   Mean for Hourly Rate: 32.7886
#   Median for Hourly Rate: 35.6000
#   Standard Desviation for Hourly Rate: 12.1126
#   Standard Error of the Mean (SEM) for Hourly Rate: 0.1352
#
# Hypothesis test results:
#   t-statistic: 20.62
#   p-value: 4.32e-92

# %%
# Results Interpretation
print("\nConclusion: ", end="")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. The average salary is significantly different from $30/hr.")
else:
    print('''The null hypothesis cannot be rejected.
There is not enough evidence to state that the average salary is different from $30/hr.''')
# Out:
# Conclusion: Reject the null hypothesis. The average salary is significantly different from $30/hr.

# %% [markdown]
# # Challenge 3 - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# Calculate the 95% confidence interval
confidence_level = 0.95
degrees_of_freedom = len(hourly_rates) - 1
confidence_interval = t.interval(confidence_level, degrees_of_freedom, loc=mean_hourly_rate, scale=sem_hourly_rate)

# Perform the hypothesis test (one-sample t-test)
# Null hypothesis (H0): The average salary is equal to $30/hr
# Alternative hypothesis (H1): The average salary is different from $30/hr
population_mean = 30
t_stat, p_value = ttest_1samp(hourly_rates, population_mean)

print("\nDescriptive stats results:")
print(f"  Mean: {mean_hourly_rate:.4f}")
print(f"  Median: {median_hourly_rate:.4f}")
print(f"  Standard Desviation: {std_dev_hourly_rate:.4f}")
print(f"  Standard Error of the Mean (SEM): {sem_hourly_rate:.4f}")

print("\n95% Confidence Interval for the average hourly salary:")
print(f"  Lower Limit: {confidence_interval[0]:.2f}")
print(f"  Superior Limit: {confidence_interval[1]:.2f}")

print("\nHypothesis test results:")
print(f"  t-statistic: {t_stat:.2f}")
print(f"  p-value: {p_value:.2e}")

# Results Interpretation
print("\nConclusion: ", end="")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. The average salary is significantly different from $30/hr.")
else:
    print('''The null hypothesis cannot be rejected.
There is not enough evidence to state that the average salary is different from $30/hr.''')
# Out:
# Descriptive stats results:
#   Mean: 32.7886
#   Median: 35.6000
#   Standard Desviation: 12.1126
#   Standard Error of the Mean (SEM): 0.1352
#
# 95% Confidence Interval for the average hourly salary:
#   Lower Limit: 32.52
#   Superior Limit: 33.05
#
# Hypothesis test results:
#   t-statistic: 20.62
#   p-value: 4.32e-92
#
# Conclusion: Reject the null hypothesis. The average salary is significantly different from $30/hr.

# %% [markdown]
# # Challenge 4 - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Proportion of hourly workers compared to the total:
n_total = len(data)
n_hourly = len(hourly_workers)
proportion_hourly = n_hourly / n_total

# Perform the hypothesis test for proportions
# Null hypothesis (H0): The proportion of hourly workers is equal to 25% (0.25)
# Alternative hypothesis (H1): The proportion of hourly workers is different from 25% (0.25)
null_hypothesis_proportion = 0.25
count = n_hourly
nobs = n_total
z_stat, p_value_proportion = proportions_ztest(count, nobs, value=null_hypothesis_proportion)

# Print Results
print("\nDescriptive stats results:")
print(f"  Mean: {mean_hourly_rate:.4f}")
print(f"  Median: {median_hourly_rate:.4f}")
print(f"  Standard Desviation: {std_dev_hourly_rate:.4f}")
print(f"  Standard Error of the Mean (SEM): {sem_hourly_rate:.4f}")

print("\n95% Confidence Interval for the average hourly salary:")
print(f"  Lower Limit: {confidence_interval[0]:.2f}")
print(f"  Superior Limit: {confidence_interval[1]:.2f}")

print("\nHypothesis test results (salaries):")
print(f"t-statistic: {t_stat:.2f}")
print(f"p-value: {p_value:.2e}")

print("\nHypothesis test results (proportions):")
print(f"z-statistic: {z_stat:.2f}")
print(f"p-value: {p_value_proportion:.2e}")

# Results Interpretation
print("\nConclusion about salaries: ", end="")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. The average salary is significantly different from $30/hr.")
else:
    print("The null hypothesis cannot be rejected. There is not enough evidence to state that the average salary is different from $30/hr.")

print("\nConclusion about proportions: ", end="")

if p_value_proportion < alpha:
    print("Reject the null hypothesis. The proportion of hourly workers is significantly different from 25%.")
else:
    print("The null hypothesis cannot be rejected. There is not enough evidence to state that the proportion of hourly workers is different from 25%.")
# Out:
# Descriptive stats results:
#   Mean: 32.7886
#   Median: 35.6000
#   Standard Desviation: 12.1126
#   Standard Error of the Mean (SEM): 0.1352
#
# 95% Confidence Interval for the average hourly salary:
#   Lower Limit: 32.52
#   Superior Limit: 33.05
#
# Hypothesis test results (salaries):
# t-statistic: 20.62
# p-value: 4.32e-92
#
# Hypothesis test results (proportions):
# z-statistic: -3.51
# p-value: 4.48e-04
#
# Conclusion about salaries: Reject the null hypothesis. The average salary is significantly different from $30/hr.
#
# Conclusion about proportions: Reject the null hypothesis. The proportion of hourly workers is significantly different from 25%.
